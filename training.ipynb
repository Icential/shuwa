# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
df = pd.read_csv("signs_en.csv")
df = df.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], axis=1)
df
# Out:
#       Landmark 1 x  Landmark 1 y  Landmark 2 x  Landmark 2 y  Landmark 3 x  \
# 0         0.447142      0.590708      0.469595      0.513098      0.471293
# 1         0.447354      0.598270      0.470890      0.518473      0.474211
# 2         0.447751      0.594389      0.471821      0.516508      0.474668
# 3         0.447579      0.594926      0.471340      0.515999      0.474191
# 4         0.448942      0.590661      0.472229      0.511420      0.474214
# ...            ...           ...           ...           ...           ...
# 3639      0.426360      0.724562      0.461132      0.709521      0.488471
# 3640      0.449642      0.615772      0.466218      0.597665      0.476489
# 3641      0.425549      0.727048      0.460003      0.712052      0.487133
# 3642      0.448296      0.616143      0.466066      0.598424      0.477857
# 3643      0.424904      0.726998      0.459803      0.711761      0.487291
#
#       Landmark 3 y  Landmark 4 x  Landmark 4 y  Landmark 5 x  Landmark 5 y  \
# 0         0.451205      0.455870      0.405068      0.504342      0.515647
# 1         0.456242      0.458783      0.407200      0.505914      0.514490
# 2         0.455287      0.459516      0.407649      0.507784      0.514943
# 3         0.453736      0.458233      0.405407      0.507447      0.514900
# 4         0.448855      0.457358      0.401411      0.509540      0.506018
# ...            ...           ...           ...           ...           ...
# 3639      0.700905      0.498030      0.686417      0.449237      0.622028
# 3640      0.588239      0.481915      0.585716      0.455635      0.546481
# 3641      0.702744      0.498550      0.686281      0.450705      0.624515
# 3642      0.589754      0.484474      0.588223      0.455346      0.547128
# 3643      0.702356      0.498245      0.685870      0.449958      0.624394
#
#       ...  Landmark 16 y  Landmark 17 x  Landmark 17 y  Landmark 18 x  \
# 0     ...       0.630833       0.518164       0.645377       0.555401
# 1     ...       0.634632       0.518493       0.648955       0.557850
# 2     ...       0.634539       0.519102       0.647704       0.561070
# 3     ...       0.636172       0.520290       0.647888       0.561078
# 4     ...       0.629209       0.520169       0.637428       0.560247
# ...   ...            ...            ...            ...            ...
# 3639  ...       0.597029       0.414894       0.626698       0.426728
# 3640  ...       0.604166       0.424647       0.572171       0.444889
# 3641  ...       0.595984       0.414058       0.627085       0.425565
# 3642  ...       0.603929       0.424749       0.571958       0.444960
# 3643  ...       0.596008       0.413996       0.627434       0.425285
#
#       Landmark 18 y  Landmark 19 x  Landmark 19 y  Landmark 20 x  \
# 0          0.660619       0.535724       0.671495       0.516766
# 1          0.663069       0.536107       0.673253       0.514505
# 2          0.663423       0.539275       0.672495       0.516909
# 3          0.664179       0.539073       0.673748       0.516713
# 4          0.658442       0.537632       0.668001       0.514961
# ...             ...            ...            ...            ...
# 3639       0.582988       0.445991       0.584739       0.455846
# 3640       0.579529       0.455239       0.592205       0.460785
# 3641       0.583809       0.444934       0.585648       0.455613
# 3642       0.578938       0.455473       0.591537       0.461400
# 3643       0.584062       0.444677       0.585607       0.455726
#
#       Landmark 20 y  Label
# 0          0.669519   good
# 1          0.670299   good
# 2          0.668556   good
# 3          0.669505   good
# 4          0.662070   good
# ...             ...    ...
# 3639       0.601655      c
# 3640       0.602678      c
# 3641       0.602743      c
# 3642       0.602296      c
# 3643       0.602457      c
#
# [3644 rows x 41 columns]

# %%
X = df.drop(columns="Label", axis=1)
y = df["Label"]
y
# Out:
# 0       good
# 1       good
# 2       good
# 3       good
# 4       good
#         ...
# 3639       c
# 3640       c
# 3641       c
# 3642       c
# 3643       c
# Name: Label, Length: 3644, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9986282578875172

# %%
clf.predict(np.expand_dims(X_test.iloc[0].to_numpy(), axis=0))[0]
# Out:
# c:\Users\paoma\miniconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 'not good'

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(clf, f)
